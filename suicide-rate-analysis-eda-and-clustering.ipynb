# %% [markdown]
# <font size="5">EDA and Visualization</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")
plt.style.use('ggplot')

# %%
df = pd.read_csv("../input/master.csv")
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
df.shape
# Out:
# (27820, 12)

# %%
## Summarizing the data
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# max        0.944000       126352.000000

# %%
## Renaming some columns for better interpretation
df.rename(columns={" gdp_for_year ($) ":
                  "gdp_for_year", "gdp_per_capita ($)":
                  "gdp_per_capita"}, inplace=True)
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year   gdp_for_year  \
# 0               6.71  Albania1987           NaN  2,156,624,900
# 1               5.19  Albania1987           NaN  2,156,624,900
# 2               4.83  Albania1987           NaN  2,156,624,900
# 3               4.59  Albania1987           NaN  2,156,624,900
# 4               3.28  Albania1987           NaN  2,156,624,900
#
#    gdp_per_capita       generation
# 0             796     Generation X
# 1             796           Silent
# 2             796     Generation X
# 3             796  G.I. Generation
# 4             796          Boomers

# %%
## Suicides number curve (1985-2016)
ns = df['suicides_no'].groupby(df.year).sum()
ns.plot(figsize=(8,6), linewidth=2, fontsize=15,color='black')
plt.xlabel('year', fontsize=15)
plt.ylabel('suicides_no',fontsize=15)
# Out:
# Text(0, 0.5, 'suicides_no')

# %% [markdown]
# <font size="2">According to this plot numbers of suicides had been decreasing overall</font>

# %%
## Mean suicides number by gender and 100k population
df["year"] = pd.to_datetime(df["year"], format = "%Y")
data = df.groupby(["year", "sex"]).agg("mean").reset_index()
sns.lineplot(x = "year", y = "suicides/100k pop", hue = "sex", data = df)
plt.xlim("1985", "2015")
plt.title("Evolution of the mean suicides number per 100k population (1985 - 2015)");

# %%
df = df.groupby(["year", "sex", "age"]).agg("mean").reset_index()

sns.relplot(x = "year", y = "suicides/100k pop", 
            hue = "sex", col = "age", col_wrap = 3, data = df, 
            facet_kws=dict(sharey=False), kind = "line")

plt.xlim("1985", "2015")
plt.subplots_adjust(top = 0.9)
plt.suptitle("Evolution of suicide by sex and age category (1985 - 2015)", size=15);

# %%
## Number of suicides in 1985
year_1985 = df[(df['year'] == 1985)]
year_1985 = year_1985.groupby('country')[['suicides_no']].sum().reset_index()

## Sorting values in ascending order
year_1985 = year_1985.sort_values(by='suicides_no', ascending=False)

## Styling output dataframe
year_1985.style.background_gradient(cmap='Purples', subset=['suicides_no'])
# Out:
# <style  type="text/css" >
#     #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow1_col1 {
#             background-color:  #63439c;
#             color:  #f1f1f1;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow2_col1 {
#             background-color:  #b0afd4;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow3_col1 {
#             background-color:  #e4e3f0;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow4_col1 {
#             background-color:  #e7e6f1;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow5_col1 {
#             background-color:  #e9e8f2;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow6_col1 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow7_col1 {
#             background-color:  #efedf5;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow8_col1 {
#             background-color:  #f1eff6;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow9_col1 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow10_col1 {
#             background-color:  #f3f2f8;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow11_col1 {
#             background-color:  #f4f3f8;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow12_col1 {
#             background-color:  #f5f3f8;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow13_col1 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow14_col1 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow15_col1 {
#             background-color:  #f6f5f9;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow16_col1 {
#             background-color:  #f7f5fa;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow17_col1 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow18_col1 {
#             background-color:  #f9f7fb;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow19_col1 {
#             background-color:  #f9f7fb;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow20_col1 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow21_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow22_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow23_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow24_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow25_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow26_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow27_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow28_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow29_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow30_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow31_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow32_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow33_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow34_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow35_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow36_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow37_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow38_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow39_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow40_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow41_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow42_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow43_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow44_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow45_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow46_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow47_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >suicides_no</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8alevel0_row0" class="row_heading level0 row0" >46</th>
#                         <td id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow0_col0" class="data row0 col0" >United States</td>
#                         <td id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow0_col1" class="data row0 col1" >29446</td>
#             </tr>
#             <tr>
#                         <th id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8alevel0_row1" class="row_heading level0 row1" >24</th>
#                         <td id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow1_col0" class="data row1 col0" >Japan</td>
#                         <td id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow1_col1" class="data row1 col1" >23257</td>
#             </tr>
#             <tr>
#                         <th id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8alevel0_row2" class="row_heading level0 row2" >16</th>
#                         <td id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow2_col0" class="data row2 col0" >France</td>
#                         <td id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8arow2_col1" class="data row2 col1" >12501</td>
#             </tr>
#             <tr>
#                         <th id="T_4e9a5d8c_bda6_11ea_afb2_d94bff1c9a8alevel0_row3" class="ro

# %%
#Number of suicides in 2016
year_2016 = df[(df['year'] == 2016)]
year_2016 = year_2016.groupby('country')[['suicides_no']].sum().reset_index()

# Sort values in ascending order
year_2016 = year_2016.sort_values(by='suicides_no', ascending=False)

# Styling output dataframe
year_2016.style.background_gradient(cmap='Oranges', subset=['suicides_no'])
# Out:
# <style  type="text/css" >
#     #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow0_col1 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow1_col1 {
#             background-color:  #fd9446;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow2_col1 {
#             background-color:  #fd984b;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow3_col1 {
#             background-color:  #fda057;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow4_col1 {
#             background-color:  #fdbe84;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow5_col1 {
#             background-color:  #fdc590;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow6_col1 {
#             background-color:  #fdc997;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow7_col1 {
#             background-color:  #fdd9b4;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow8_col1 {
#             background-color:  #fedfc0;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow9_col1 {
#             background-color:  #fee9d3;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow10_col1 {
#             background-color:  #fff2e6;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow11_col1 {
#             background-color:  #fff3e7;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow12_col1 {
#             background-color:  #fff3e7;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow13_col1 {
#             background-color:  #fff4e9;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow14_col1 {
#             background-color:  #fff4e9;
#             color:  #000000;
#         }    #T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow15_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }</style><table id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >suicides_no</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow0_col0" class="data row0 col0" >Thailand</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow0_col1" class="data row0 col1" >4117</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row1" class="row_heading level0 row1" >13</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow1_col0" class="data row1 col0" >Romania</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow1_col1" class="data row1 col1" >1953</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row2" class="row_heading level0 row2" >11</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow2_col0" class="data row2 col0" >Netherlands</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow2_col1" class="data row2 col1" >1886</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow3_col0" class="data row3 col0" >Hungary</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow3_col1" class="data row3 col1" >1761</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow4_col0" class="data row4 col0" >Czech Republic</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow4_col1" class="data row4 col1" >1318</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row5" class="row_heading level0 row5" >1</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow5_col0" class="data row5 col0" >Austria</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow5_col1" class="data row5 col1" >1201</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row6" class="row_heading level0 row6" >14</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow6_col0" class="data row6 col0" >Sweden</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow6_col1" class="data row6 col1" >1130</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow7_col0" class="data row7 col0" >Lithuania</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow7_col1" class="data row7 col1" >822</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row8" class="row_heading level0 row8" >2</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow8_col0" class="data row8 col0" >Croatia</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow8_col1" class="data row8 col1" >683</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow9_col0" class="data row9 col0" >Mongolia</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow9_col1" class="data row9 col1" >423</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row10" class="row_heading level0 row10" >9</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow10_col0" class="data row10 col0" >Mauritius</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow10_col1" class="data row10 col1" >98</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row11" class="row_heading level0 row11" >12</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow11_col0" class="data row11 col0" >Qatar</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow11_col1" class="data row11 col1" >68</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row12" class="row_heading level0 row12" >0</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow12_col0" class="data row12 col0" >Armenia</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow12_col1" class="data row12 col1" >67</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8alevel0_row13" class="row_heading level0 row13" >7</th>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow13_col0" class="data row13 col0" >Iceland</td>
#                         <td id="T_555f2062_bda6_11ea_afb2_d94bff1c9a8arow13_col1" class="data row13 col1" >40</td>
#             </tr>
#             <tr>
#                         <th id="T_555f2062_bda6_11ea_af

# %%
## Suicides number by generation and sex
f,ax = plt.subplots(1,1,figsize=(13,6))
ax = sns.barplot(x = df['generation'], y = 'suicides_no',
                  hue='sex',data=df, palette='autumn')

# %%
## Suicides number by age and sex
f,ax = plt.subplots(1,1,figsize=(13,6))
ax = sns.barplot(x = df['age'], y = 'suicides_no',
                  hue='sex',data=df, palette='Accent')

# %% [markdown]
# <font size="2">These barplots show that generation of boomers have the highest suicide rate, males in general are more likely to commit suicides than females as well as people from age groups 35-54 yrs and 55-74 yrs</font>

# %%
## Suicides number by year
f,ax = plt.subplots(1,1,figsize=(16,6))
ax = sns.barplot(x = df['year'], y = 'suicides_no',
                data=df, palette='Spectral')

# %%
## Correlation of features
f,ax = plt.subplots(1,1,figsize=(10,10))
ax = sns.heatmap(df.corr(),annot=True, cmap='coolwarm')

# %% [markdown]
# <font size="2">The correlation between the factors except population with GDP for year is low</font>

# %%
data = df['suicides_no'].groupby(df.country).sum().sort_values(ascending=False)
f,ax = plt.subplots(1,1,figsize=(10,20))
ax = sns.barplot(data.head(20), data.head(20).index, palette='Reds_r')

# %% [markdown]
# <font size="2">The highest number of suicides is in Russian Federation</font>

# %%
data = df['suicides_no'].groupby(df.country).sum().sort_values(ascending=False)
f,ax = plt.subplots(1,1,figsize=(10,20))
ax = sns.barplot(data.tail(20),data.tail(20).index,palette='Blues_r')

# %% [markdown]
# <font size="2">The lowest number of suicides is in San Marino</font>

# %%
## Suicides number by year (high to low)
year_suicides = df.groupby('year')[['suicides_no']].sum().reset_index()
year_suicides.sort_values(by='suicides_no', ascending=False).style.background_gradient(cmap='Greens', subset=['suicides_no'])
# Out:
# <style  type="text/css" >
#     #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow1_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow2_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow3_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow4_col1 {
#             background-color:  #004a1e;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow5_col1 {
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow6_col1 {
#             background-color:  #005020;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow7_col1 {
#             background-color:  #005522;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow8_col1 {
#             background-color:  #005522;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow9_col1 {
#             background-color:  #005924;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow10_col1 {
#             background-color:  #005924;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow11_col1 {
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow12_col1 {
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow13_col1 {
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow14_col1 {
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow15_col1 {
#             background-color:  #006328;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow16_col1 {
#             background-color:  #006328;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow17_col1 {
#             background-color:  #006428;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow18_col1 {
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow19_col1 {
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow20_col1 {
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow21_col1 {
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow22_col1 {
#             background-color:  #117b38;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow23_col1 {
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow24_col1 {
#             background-color:  #208843;
#             color:  #000000;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow25_col1 {
#             background-color:  #258d47;
#             color:  #000000;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow26_col1 {
#             background-color:  #4bb062;
#             color:  #000000;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow27_col1 {
#             background-color:  #81ca81;
#             color:  #000000;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow28_col1 {
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow29_col1 {
#             background-color:  #8bcf89;
#             color:  #000000;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow30_col1 {
#             background-color:  #92d28f;
#             color:  #000000;
#         }    #T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow31_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >year</th>        <th class="col_heading level0 col1" >suicides_no</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row0" class="row_heading level0 row0" >14</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow0_col0" class="data row0 col0" >1999</td>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow0_col1" class="data row0 col1" >256119</td>
#             </tr>
#             <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row1" class="row_heading level0 row1" >17</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow1_col0" class="data row1 col0" >2002</td>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow1_col1" class="data row1 col1" >256095</td>
#             </tr>
#             <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row2" class="row_heading level0 row2" >18</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow2_col0" class="data row2 col0" >2003</td>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow2_col1" class="data row2 col1" >256079</td>
#             </tr>
#             <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow3_col0" class="data row3 col0" >2000</td>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow3_col1" class="data row3 col1" >255832</td>
#             </tr>
#             <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row4" class="row_heading level0 row4" >16</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow4_col0" class="data row4 col0" >2001</td>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow4_col1" class="data row4 col1" >250652</td>
#             </tr>
#             <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row5" class="row_heading level0 row5" >13</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow5_col0" class="data row5 col0" >1998</td>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow5_col1" class="data row5 col1" >249591</td>
#             </tr>
#             <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row6" class="row_heading level0 row6" >11</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow6_col0" class="data row6 col0" >1996</td>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow6_col1" class="data row6 col1" >246725</td>
#             </tr>
#             <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row7" class="row_heading level0 row7" >10</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow7_col0" class="data row7 col0" >1995</td>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow7_col1" class="data row7 col1" >243544</td>
#             </tr>
#             <tr>
#                         <th id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8alevel0_row8" class="row_heading level0 row8" >24</th>
#                         <td id="T_54015b24_bda9_11ea_afb2_d94bff1c9a8arow8_col0" class="data row8 col0" >2009</td>
#                         <td id="T_54015b24_bda9_11ea_a

# %% [markdown]
# <font size=2>The highest number of suicides was in 1999 and the lowest in 2016</font>

# %%
## Suicides number by age group
age_grp = df.groupby('age')[['suicides_no']].sum().reset_index()
age_grp.sort_values(by='suicides_no', ascending=False).style.background_gradient(cmap='Greys', subset=['suicides_no'])
# Out:
# <style  type="text/css" >
#     #T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow1_col1 {
#             background-color:  #676767;
#             color:  #f1f1f1;
#         }    #T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow2_col1 {
#             background-color:  #a7a7a7;
#             color:  #000000;
#         }    #T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow3_col1 {
#             background-color:  #cbcbcb;
#             color:  #000000;
#         }    #T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow4_col1 {
#             background-color:  #d9d9d9;
#             color:  #000000;
#         }    #T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow5_col1 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }</style><table id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >suicides_no</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8alevel0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow0_col0" class="data row0 col0" >35-54 years</td>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow0_col1" class="data row0 col1" >2452141</td>
#             </tr>
#             <tr>
#                         <th id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8alevel0_row1" class="row_heading level0 row1" >4</th>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow1_col0" class="data row1 col0" >55-74 years</td>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow1_col1" class="data row1 col1" >1658443</td>
#             </tr>
#             <tr>
#                         <th id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8alevel0_row2" class="row_heading level0 row2" >1</th>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow2_col0" class="data row2 col0" >25-34 years</td>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow2_col1" class="data row2 col1" >1123912</td>
#             </tr>
#             <tr>
#                         <th id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8alevel0_row3" class="row_heading level0 row3" >0</th>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow3_col0" class="data row3 col0" >15-24 years</td>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow3_col1" class="data row3 col1" >808542</td>
#             </tr>
#             <tr>
#                         <th id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8alevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow4_col0" class="data row4 col0" >75+ years</td>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow4_col1" class="data row4 col1" >653118</td>
#             </tr>
#             <tr>
#                         <th id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8alevel0_row5" class="row_heading level0 row5" >3</th>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow5_col0" class="data row5 col0" >5-14 years</td>
#                         <td id="T_56f10b90_bda9_11ea_afb2_d94bff1c9a8arow5_col1" class="data row5 col1" >52264</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <font size=2> People with age 35-54 and 55-74 committed suicides the most</font>

# %%
## Suicides number per 100k population
per100k = df.groupby(['country', 'year'])[['suicides/100k pop']].sum().reset_index()
per100k.sort_values(by='suicides/100k pop', ascending=False).head(20).style.background_gradient(cmap='Reds', subset=['suicides/100k pop'])
# Out:
# <style  type="text/css" >
#     #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow1_col2 {
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow2_col2 {
#             background-color:  #fc8464;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow3_col2 {
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow4_col2 {
#             background-color:  #fc9272;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow5_col2 {
#             background-color:  #fc9576;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow6_col2 {
#             background-color:  #fc997a;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow7_col2 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow8_col2 {
#             background-color:  #fca082;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow9_col2 {
#             background-color:  #fcad90;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow10_col2 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow11_col2 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow12_col2 {
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow13_col2 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow14_col2 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow15_col2 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow16_col2 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow17_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow18_col2 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow19_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >year</th>        <th class="col_heading level0 col2" >suicides/100k pop</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row0" class="row_heading level0 row0" >1255</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow0_col0" class="data row0 col0" >Lithuania</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow0_col1" class="data row0 col1" >1995</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow0_col2" class="data row0 col2" >639.3</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row1" class="row_heading level0 row1" >1256</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow1_col0" class="data row1 col0" >Lithuania</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow1_col1" class="data row1 col1" >1996</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow1_col2" class="data row1 col2" >595.61</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row2" class="row_heading level0 row2" >948</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow2_col0" class="data row2 col0" >Hungary</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow2_col1" class="data row2 col1" >1991</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow2_col2" class="data row2 col2" >575</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row3" class="row_heading level0 row3" >1260</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow3_col0" class="data row3 col0" >Lithuania</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow3_col1" class="data row3 col1" >2000</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow3_col2" class="data row3 col2" >571.8</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row4" class="row_heading level0 row4" >949</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow4_col0" class="data row4 col0" >Hungary</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow4_col1" class="data row4 col1" >1992</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow4_col2" class="data row4 col2" >570.26</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row5" class="row_heading level0 row5" >1261</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow5_col0" class="data row5 col0" >Lithuania</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow5_col1" class="data row5 col1" >2001</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow5_col2" class="data row5 col2" >568.98</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row6" class="row_heading level0 row6" >1752</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow6_col0" class="data row6 col0" >Russian Federation</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow6_col1" class="data row6 col1" >1994</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow6_col2" class="data row6 col2" >567.64</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row7" class="row_heading level0 row7" >1258</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow7_col0" class="data row7 col0" >Lithuania</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow7_col1" class="data row7 col1" >1998</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow7_col2" class="data row7 col2" >566.36</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row8" class="row_heading level0 row8" >1257</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow8_col0" class="data row8 col0" >Lithuania</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow8_col1" class="data row8 col1" >1997</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow8_col2" class="data row8 col2" >565.44</td>
#             </tr>
#             <tr>
#                         <th id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8alevel0_row9" class="row_heading level0 row9" >1259</th>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow9_col0" class="data row9 col0" >Lithuania</td>
#                         <td id="T_5ab97e60_bda9_11ea_afb2_d94bff1c9a8arow9_col1" class="data row9 col1" >

# %% [markdown]
# <font size=2> Lithuania has the highest number of suicides per 100k population </font>

# %% [markdown]
# <font size="2">There are missing values in our dataset (HDI for year). Let's check how many</font>

# %%
df.count()
# Out:
# country              27820
# year                 27820
# sex                  27820
# age                  27820
# suicides_no          27820
# population           27820
# suicides/100k pop    27820
# country-year         27820
# HDI for year          8364
# gdp_for_year         27820
# gdp_per_capita       27820
# generation           27820
# dtype: int64

# %% [markdown]
# <font size="2">Since HDI for year is continious, we can fill those missing values with mean values</font>

# %%
df.fillna(df.mean(), inplace=True)

## We don't need the column "country-year", so we'll just drop it
df.drop("country-year", axis=1, inplace=True)
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop  HDI for year   gdp_for_year  gdp_per_capita  \
# 0               6.71      0.776601  2,156,624,900             796
# 1               5.19      0.776601  2,156,624,900             796
# 2               4.83      0.776601  2,156,624,900             796
# 3               4.59      0.776601  2,156,624,900             796
# 4               3.28      0.776601  2,156,624,900             796
#
#         generation
# 0     Generation X
# 1           Silent
# 2     Generation X
# 3  G.I. Generation
# 4          Boomers

# %%
df.count()
# Out:
# country              27820
# year                 27820
# sex                  27820
# age                  27820
# suicides_no          27820
# population           27820
# suicides/100k pop    27820
# HDI for year         27820
# gdp_for_year         27820
# gdp_per_capita       27820
# generation           27820
# dtype: int64

# %% [markdown]
# <font size="2">As we can see, there are no missing values anymore. Now we need to check the type of our data</font>

# %%
df.dtypes
# Out:
# country               object
# year                   int64
# sex                   object
# age                   object
# suicides_no            int64
# population             int64
# suicides/100k pop    float64
# HDI for year         float64
# gdp_for_year          object
# gdp_per_capita         int64
# generation            object
# dtype: object

# %%
(df.dtypes=="object").index[df.dtypes=="object"]
# Out:
# Index(['country', 'sex', 'age', 'gdp_for_year', 'generation'], dtype='object')

# %%
## Turning object types into category and integer types
df[["country","age","sex","generation"]] = df[["country","age","sex","generation"]].astype("category")
## Converting number strings with commas into integer
df['gdp_for_year'] = df['gdp_for_year'].str.replace(",", "").astype("int")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 11 columns):
# country              27820 non-null category
# year                 27820 non-null int64
# sex                  27820 non-null category
# age                  27820 non-null category
# suicides_no          27820 non-null int64
# population           27820 non-null int64
# suicides/100k pop    27820 non-null float64
# HDI for year         27820 non-null float64
# gdp_for_year         27820 non-null int64
# gdp_per_capita       27820 non-null int64
# generation           27820 non-null category
# dtypes: category(4), float64(2), int64(5)
# memory usage: 1.6 MB

# %%
## Checking the relationship between gdp for year and number of suicides
f, ax = plt.subplots(1,1, figsize=(10,8))
ax = sns.scatterplot(x="gdp_for_year", y="suicides_no", data=df, color='purple')

# %% [markdown]
# <font size="2">The relationship between "gdp_for_year" and "suicides_no" is not linear. Hence, GDP is not something that has a real impact on suicide rate </font>

# %%
## Checking the relationship between gdp per capita and number of suicides
f, ax = plt.subplots(1,1, figsize=(10,8))
ax = sns.scatterplot(x="gdp_per_capita", y="suicides_no", data=df, color='yellow')

# %% [markdown]
# <font size=2> Again, GDP has no real impact on suicide rate </font>

# %%
## Checking the relationship between Hdi and number of suicides
f, ax = plt.subplots(1,1, figsize=(10,8))
ax = sns.scatterplot(x="HDI for year", y="suicides_no", data=df, color='cyan')

# %%
##Suicides by age and gender in Russian Federation
f, ax = plt.subplots(1,1, figsize=(10,10))
ax = sns.boxplot(x='age', y='suicides_no', hue='sex',
                 data=df[df['country']=='Russian Federation'],
                 palette='Set1')

# %% [markdown]
# <font size='2'> Males in Russia aged from 35 to 54 yrs and females aged 55-74 yrs commit suicide more often </font>

# %%
##Suicides by age and gender in Brazil
f, ax = plt.subplots(1,1, figsize=(10,10))
ax = sns.boxplot(x='age', y='suicides_no', hue='sex',
                 data=df[df['country']=='Brazil'],
                 palette='Set2')

# %% [markdown]
# <font size='2'> In Brazil both males and females commit suicides mostly at age 35-54 </font>

# %% [markdown]
# <font size="5">Machine Learning</font>

# %%
## Using cat.codes method to convert category into numerical labels
columns = df.select_dtypes(['category']).columns
df[columns] = df[columns].apply(lambda fx: fx.cat.codes)
df.dtypes
# Out:
# country                 int8
# year                   int64
# sex                     int8
# age                     int8
# suicides_no            int64
# population             int64
# suicides/100k pop    float64
# HDI for year         float64
# gdp_for_year           int64
# gdp_per_capita         int64
# generation              int8
# dtype: object

# %% [markdown]
# <font size="3">**K-means Clustering**<font>

# %% [markdown]
# <font size='2'>The task is to cluster the countries into two groups - the ones with high number of suicides and the ones with low number of suicides. For that we have to drop the 'suicides_no' column from the dataset and make it unlabeled</font>

# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
x = df.drop('suicides_no', axis=True)
y = df['suicides_no']
kmeans = KMeans(n_clusters=2)
kmeans.fit(x)
KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=600,
    n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
    random_state=0, tol=0.0001, verbose=0)
y_kmeans = kmeans.predict(x)
x, y_kmeans = make_blobs(n_samples=600, centers=2, cluster_std=0.60, random_state=0)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x[:,0], x[:,1], c=y_kmeans, cmap='cool')

# %%
from sklearn.metrics import silhouette_score
print(silhouette_score(x, y_kmeans))
# Out:
# 0.7107290505066528

# %% [markdown]
# <font size='2'>Great! The model was able to cluster correctly with a 71% without even tweaking any parameters of the model itself and scaling the values of the features</font>

# %% [markdown]
# <font size='5'>Conclusions</font>

# %% [markdown]
# <font size='2'>Data cleaning is very important, as real world data is usually messy. Visualizing the data is also a very important step because it makes it easier for a lot of people to understand the data and detect patterns, trends and outliers. K-means clustering algorithm (which found a strong structure in our dataset) was easy to implement in this case, since we had some domain knowledge that told us the number of suicides committed by people in different countries, so we didn't have to pre-specify the number of clusters(k). However, this doesn't always happen that way. As for suicides and factors that influence them one can say while age and gender can be some of those factors, Gdp and Hdi not really, because even in countries with high Gdp and Hdi a lot of people commit suicide. Other than that, there's not enough data available for better analysis, as there are other biological, psychological and social factors that may cause suicides (race, ethnicity, social isolation, contagion, religion, etc.), as well as geographical (climate)</font>
